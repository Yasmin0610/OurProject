# %%
import pandas as pd
# %matplotlib notebook
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
df = pd.read_csv(r'C:\Users\Maya\Desktop\Drawing6.csv', sep =',')

# %%
df
# Out:
#                                                      X           Y   Pressure  \
# 0                                          758.0163991  569.381222   0.088853
# 1                                          758.0690611  569.170574   0.108629
# 2                                          758.0690611  569.170574   0.141833
# 3                                          758.0690611  569.170574   0.170397
# 4                                          758.0690611  569.170574   0.186267
# ...                                                ...         ...        ...
# 1106                                       779.2918351  635.577318   0.745113
# 1107                                       779.2918351  635.577318   0.737301
# 1108                                       779.2918351  635.577318   0.711910
# 1109  Time Elapsed till drawing started: 00:02.7042668         NaN        NaN
# 1110   Time Elapsed till drawing submit: 00:16.8506948         NaN        NaN
#
#        TiltX   TiltY     Time
# 0    -4282.0  2245.0  00:02.7
# 1    -4282.0  2245.0  00:02.7
# 2    -4011.0  2058.0  00:02.7
# 3    -3961.0  2025.0  00:02.8
# 4    -3961.0  2025.0  00:02.8
# ...      ...     ...      ...
# 1106 -3373.0  1415.0  00:15.7
# 1107 -3373.0  1415.0  00:15.7
# 1108 -3373.0  1415.0  00:15.8
# 1109     NaN     NaN      NaN
# 1110     NaN     NaN      NaN
#
# [1111 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   X          1111 non-null   object
#  1   Y          1109 non-null   float64
#  2    Pressure  1109 non-null   float64
#  3    TiltX     1109 non-null   float64
#  4    TiltY     1109 non-null   float64
#  5    Time      1109 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 52.2+ KB

# %%
df = df.drop(df.index[[-1,-2]])

df
# Out:
#                 X           Y   Pressure   TiltX   TiltY     Time
# 0     758.0163991  569.381222   0.088853 -4282.0  2245.0  00:02.7
# 1     758.0690611  569.170574   0.108629 -4282.0  2245.0  00:02.7
# 2     758.0690611  569.170574   0.141833 -4011.0  2058.0  00:02.7
# 3     758.0690611  569.170574   0.170397 -3961.0  2025.0  00:02.8
# 4     758.0690611  569.170574   0.186267 -3961.0  2025.0  00:02.8
# ...           ...         ...        ...     ...     ...      ...
# 1104  779.2918351  635.577318   0.761227 -3373.0  1415.0  00:15.7
# 1105  779.2918351  635.577318   0.754391 -3373.0  1415.0  00:15.7
# 1106  779.2918351  635.577318   0.745113 -3373.0  1415.0  00:15.7
# 1107  779.2918351  635.577318   0.737301 -3373.0  1415.0  00:15.7
# 1108  779.2918351  635.577318   0.711910 -3373.0  1415.0  00:15.8
#
# [1109 rows x 6 columns]

# %%
df['X'] = df['X'].astype(float)

# %%
x = df['X']
y = df['Y']

fig = plt.figure()
plt.xlim(df['X'].min()-100 , df['X'].max() + 100)
plt.ylim(df['Y'].min()-100 , df['Y'].max() + 100)
graph, = plt.plot([], [], 'o')
graph
def animate(i):
    graph.set_data(x[:i+1], y[:i+1])
    return graph

ani = FuncAnimation(fig, animate, frames=len(df), interval=1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Counting lines

# %%
i = 120

# %%
average_x0 = (df.iloc[0+i,0]+ df.iloc[1+i,0]+df.iloc[2+i,0]+df.iloc[3+i,0]+df.iloc[4+i,0]+df.iloc[5+i,0]+df.iloc[6+i,0]+df.iloc[7+i,0]+df.iloc[8+i,0]+df.iloc[9+i,0])/10

average_x0
# Out:
# 735.09264349

# %%
average_y0 = (df.iloc[0+i,1]+ df.iloc[1+i,1]+df.iloc[2+i,1]+df.iloc[3+i,1]+df.iloc[4+i,1]+df.iloc[5+i,1]+df.iloc[6+i,1]+df.iloc[7+i,1]+df.iloc[8+i,1]+df.iloc[9+i,1])/10

average_y0
# Out:
# 612.9748008

# %%
i=i+40

# %%
average_x40 = (df.iloc[0+i,0]+ df.iloc[1+i,0]+df.iloc[2+i,0]+df.iloc[3+i,0]+df.iloc[4+i,0]+df.iloc[5+i,0]+df.iloc[6+i,0]+df.iloc[7+i,0]+df.iloc[8+i,0]+df.iloc[9+i,0])/10

average_x40
# Out:
# 659.82815568

# %%
average_y40 = (df.iloc[0+i,1]+ df.iloc[1+i,1]+df.iloc[2+i,1]+df.iloc[3+i,1]+df.iloc[4+i,1]+df.iloc[5+i,1]+df.iloc[6+i,1]+df.iloc[7+i,1]+df.iloc[8+i,1]+df.iloc[9+i,1])/10

average_y40
# Out:
# 625.98757361

# %%
x_dis = average_x0-average_x40
x_dis
# Out:
# 75.26448780999999

# %%
y_dis = average_y0-average_y40
y_dis
# Out:
# -13.012772810000001

# %%
firstGradient = y_dis / x_dis
firstGradient
# Out:
# -0.17289392632086795

# %%
line =1
i = 1
usedGradient = firstGradient
while i < len(df)-41:
    i = i+1
    average_y0 = (df.iloc[0+i,1]+ df.iloc[1+i,1]+df.iloc[2+i,1]+df.iloc[3+i,1]+df.iloc[4+i,1]+df.iloc[5+i,1]+df.iloc[6+i,1]+df.iloc[7+i,1]+df.iloc[8+i,1]+df.iloc[9+i,1])/10
    average_y40 = (df.iloc[0+i,1]+ df.iloc[1+i,1]+df.iloc[2+i,1]+df.iloc[3+i,1]+df.iloc[4+i,1]+df.iloc[5+i,1]+df.iloc[6+i,1]+df.iloc[7+i,1]+df.iloc[8+i,1]+df.iloc[9+i,1])/10
    average_x0 = (df.iloc[0+i,0]+ df.iloc[1+i,0]+df.iloc[2+i,0]+df.iloc[3+i,0]+df.iloc[4+i,0]+df.iloc[5+i,0]+df.iloc[6+i,0]+df.iloc[7+i,0]+df.iloc[8+i,0]+df.iloc[9+i,0])/10
    average_x40 = (df.iloc[0+i,0]+ df.iloc[1+i,0]+df.iloc[2+i,0]+df.iloc[3+i,0]+df.iloc[4+i,0]+df.iloc[5+i,0]+df.iloc[6+i,0]+df.iloc[7+i,0]+df.iloc[8+i,0]+df.iloc[9+i,0])/10

    x_dis = average_x0-average_x40
    y_dis = average_y0-average_y40

    curGradient = y_dis / x_dis
    if x_dis == 0:
        x_dis = 1
    
    if curGradient - usedGradient >= 10:
        line = line+1
        usedGradient = curGradient
        line
# Out:
# <ipython-input-152-304b9da00aaa>:14: RuntimeWarning: invalid value encountered in double_scalars
#   curGradient = y_dis / x_dis

# %%
Count = 0
i = 0
while i <len(df):
    gradiant = (df.iloc[i,0]-df.iloc[i+41,0])/(df.iloc[i,1]-df.iloc[i+41,1])
    i = i+1
    if ()
# Out:
#   File "<ipython-input-70-7dd32fd6b2b9>", line 6
#     if ()
#          ^
# SyntaxError: invalid syntax
